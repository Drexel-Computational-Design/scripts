# %%
from PIL import Image, ImageDraw, ImageFont

# %%
# Create Image features
font = 'Roboto-Bold.ttf'
font = ImageFont.truetype('Roboto-Bold.ttf', 50)

base = Image.open('assets/flyer-bg.png')

# Add text
draw = ImageDraw.Draw(base)
draw.text((864,700), "Project Meeting 1", (255,255,255), font=font)
# img.save()

# %%
base.size
# Out:
# (1728, 2304)

# %%
base
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1728x2304>
